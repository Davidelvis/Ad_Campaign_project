# %% [markdown]
# # AD CAMPAIGN PERFORMANCE

# %% [markdown]
# ## Business Objective
#
# The main objective of this project is to test if the ads that the advertising company runs resulted in a significant lift in brand awareness.
#
#
# ## Project workflow
#
#
# *   Setting up A/B testing framework
# *   Validating the data validity
# *   Performing A/B testing with classical, sequential and Machine learning methods
# *   Extracting statistically valid insights in relation to the  business objective

# %%
#Importing libraries that we will be using
# %matplotlib inline
# !pip install -U pandas-profiling

import statsmodels.api as sm
import numpy as np # linear algebra
import scipy.stats as stats
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from tabulate import tabulate
import pandas_profiling
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings(action="ignore")

from scipy.stats import skew, norm
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax

from sklearn.ensemble import RandomForestRegressor

# %%
#Reading our data
bio_data=pd.read_csv('/content/drive/My Drive/ABAdRecall.csv')

# %%
bio_data.head()
# Out:
#                              auction_id experiment  ... yes  no
# 0  0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  ...   0   0
# 1  000eabc5-17ce-4137-8efe-44734d914446    exposed  ...   0   0
# 2  0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  ...   0   1
# 3  00187412-2932-4542-a8ef-3633901c98d9    control  ...   0   0
# 4  001a7785-d3fe-4e11-a344-c8735acacc2c    control  ...   0   0
#
# [5 rows x 9 columns]

# %% [markdown]
# ## BIO Data Exploration

# %%
bio_data.info() # getting the information of our dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8077 entries, 0 to 8076
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   auction_id   8077 non-null   object
#  1   experiment   8077 non-null   object
#  2   date         8077 non-null   object
#  3   hour         8077 non-null   int64
#  4   device_make  8077 non-null   object
#  5   platform_os  8077 non-null   int64
#  6   browser      8077 non-null   object
#  7   yes          8077 non-null   int64
#  8   no           8077 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 568.0+ KB

# %%
#check the decoration
bio_data.columns
# Out:
# Index(['auction_id', 'experiment', 'date', 'hour', 'device_make',
#        'platform_os', 'browser', 'yes', 'no'],
#       dtype='object')

# %%
bio_data['auction_id'].nunique()
# Out:
# 8077

# %%
profile = pandas_profiling.ProfileReport(bio_data)
profile.to_file('profile_report.html')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=23.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…

# %%
profile

# %%
date_data = bio_data.groupby(['date']).agg({'date': ['count']})
date_data.columns = ['count']
date_data = date_data.reset_index()
print(tabulate(date_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════════╤═════════╕
# │    │ date       │   count │
# ╞════╪════════════╪═════════╡
# │  0 │ 2020-07-03 │    2015 │
# ├────┼────────────┼─────────┤
# │  1 │ 2020-07-04 │     903 │
# ├────┼────────────┼─────────┤
# │  2 │ 2020-07-05 │     890 │
# ├────┼────────────┼─────────┤
# │  3 │ 2020-07-06 │     490 │
# ├────┼────────────┼─────────┤
# │  4 │ 2020-07-07 │     480 │
# ╘════╧════════════╧═════════╛

# %%
fig = px.histogram(bio_data, x="date")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7e93c755-e661-49b4-a654-fc3f1cfe97f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e93c755-e661-49b4-a654-fc3f1cfe97f4")) {
#                     Plotly.newPlot(
#                         '7e93c755-e661-49b4-a654-fc3f1cfe97f4',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["2020-07-10", "2020-07-07", "2020-07-05", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-09", "2020-07-04", "2020-07-05", "2020-07-10", "2020-07-09", "2020-07-05", "2020-07-06", "2020-07-04", "2020-07-07", "2020-07-04", "2020-07-04", "2020-07-10", "2020-07-03", "2020-07-06", "2020-07-08", "2020-07-03", "2020-07-08", "2020-07-09", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-10", "2020-07-10", "2020-07-06", "2020-07-04", "2020-07-05", "2020-07-03", "2020-07-06", "2020-07-07", "2020-07-03", "2020-07-10", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-04", "2020-07-03", "2020-07-03", "2020-07-05", "2020-07-05", "2020-07-03", "2020-07-09", "2020-07-09", "2020-07-04", "2020-07-10", "2020-07-04", "2020-07-03", "2020-07-09", "2020-07-03", "2020-07-03", "2020-07-08", "2020-07-03", "2020-07-07", "2020-07-06", "2020-07-03", "2020-07-05", "2020-07-07", "2020-07-09", "2020-07-09", "2020-07-03", "2020-07-08", "2020-07-08", "2020-07-07", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-10", "2020-07-04", "2020-07-04", "2020-07-06", "2020-07-03", "2020-07-08", "2020-07-09", "2020-07-10", "2020-07-10", "2020-07-08", "2020-07-05", "2020-07-05", "2020-07-09", "2020-07-06", "2020-07-07", "2020-07-05", "2020-07-08", "2020-07-03", "2020-07-09", "2020-07-03", "2020-07-06", "2020-07-08", "2020-07-07", "2020-07-08", "2020-07-03", "2020-07-06", "2020-07-04", "2020-07-03", "2020-07-10", "2020-07-08", "2020-07-03", "2020-07-03", "2020-07-08", "2020-07-04", "2020-07-03", "2020-07-09", "2020-07-09", "2020-07-05", "2020-07-03", "2020-07-04", "2020-07-10", "2020-07-09", "2020-07-03", "2020-07-10", "2020-07-09", "2020-07-03", "2020-07-10", "2020-07-03", "2020-07-10", "2020-07-08", "2020-07-03", "2020-07-07", "2020-07-05", "2020-07-05", "2020-07-04", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-06", "2020-07-05", "2020-07-03", "2020-07-05", "2020-07-04", "2020-07-08", "2020-07-08", "2020-07-04", "2020-07-03", "2020-07-10", "2020-07-05", "2020-07-05", "2020-07-05", "2020-07-07", "2020-07-07", "2020-07-08", "2020-07-04", "2020-07-07", "2020-07-03", "2020-07-10", "2020-07-07", "2020-07-10", "2020-07-05", "2020-07-03", "2020-07-03", "2020-07-07", "2020-07-08", "2020-07-08", "2020-07-03", "2020-07-05", "2020-07-03", "2020-07-06", "2020-07-09", "2020-07-06", "2020-07-05", "2020-07-09", "2020-07-10", "2020-07-08", "2020-07-09", "2020-07-03", "2020-07-09", "2020-07-09", "2020-07-09", "2020-07-08", "2020-07-10", "2020-07-08", "2020-07-03", "2020-07-10", "2020-07-10", "2020-07-07", "2020-07-04", "2020-07-08", "2020-07-03", "2020-07-04", "2020-07-03", "2020-07-08", "2020-07-10", "2020-07-03", "2020-07-05", "2020-07-03", "2020-07-09", "2020-07-10", "2020-07-04", "2020-07-06", "2020-07-09", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-03", "2020-07-08", "2020-07-05", "2020-07-09", "2020-07-03", "2020-07-09", "2020-07-03", "2020-07-03", "2020-07-10", "2020-07-09", "2020-07-03", "2020-07-04", "2020-07-03", "2020-07-04", "2020-07-09", "2020-07-03", "2020-07-05", "2020-07-03", "2020-07-09", "2020-07-03", "2020-07-03", "2020-07-06", "2020-07-03", "2020-07-05", "2020-07-08", "2020-07-09", "2020-07-04", "2020-07-09", "2020-07-08", "2020-07-07", "2020-07-03", "2020-07-08", "2020-07-10", "2020-07-09", "2020-07-05", "2020-07-10", "2020-07-03", "2020-07-05", "2020-07-08", "2020-07-10", "2020-07-08", "2020-07-08", "2020-07-07", "2020-07-09", "2020-07-08", "2020-07-03", "2020-07-05", "2020-07-03", "2020-07-08", "2020-07-03", "2020-07-06", "2020-07-10", "2020-07-09", "2020-07-05", "2020-07-07", "2020-07-08", "2020-07-04", "2020-07-03", "2020-07-05", "2020-07-07", "2020-07-08", "2020-07-08", "2020-07-06", "2020-07-09", "2020-07 ...

# %%
hour_data = bio_data.groupby(['hour']).agg({'hour': ['count']})
hour_data.columns = ['count']
hour_data = hour_data.reset_index()
print(tabulate(hour_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════╤═════════╕
# │    │   hour │   count │
# ╞════╪════════╪═════════╡
# │  0 │      0 │     194 │
# ├────┼────────┼─────────┤
# │  1 │      1 │     222 │
# ├────┼────────┼─────────┤
# │  2 │      2 │     230 │
# ├────┼────────┼─────────┤
# │  3 │      3 │     266 │
# ├────┼────────┼─────────┤
# │  4 │      4 │     281 │
# ╘════╧════════╧═════════╛

# %%
#a function for getting the top ten users per application    
def unique_count(dataframe, variable):
    unique_values=dataframe.groupby([variable]).agg({variable: ['count']})
    unique_values.columns= ['count']
    unique_values= unique_values.reset_index
    print('Count of unique values : '+ variable)
    print('------------------------------------------------')
    print(tabulate(unique_values, headers = 'keys', tablefmt = 'fancy_grid'))

# %%
#unique_count(bio_data,'browser')

# %%
fig = px.histogram(bio_data, x="hour")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="47910efa-2a9c-4d5e-9181-73a7699dadb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("47910efa-2a9c-4d5e-9181-73a7699dadb5")) {
#                     Plotly.newPlot(
#                         '47910efa-2a9c-4d5e-9181-73a7699dadb5',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "hour=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [8, 10, 2, 15, 15, 15, 15, 5, 0, 14, 13, 6, 8, 8, 15, 16, 16, 7, 6, 15, 8, 20, 15, 4, 17, 1, 15, 15, 15, 15, 16, 1, 10, 19, 18, 15, 4, 3, 15, 2, 15, 15, 15, 17, 15, 15, 6, 17, 15, 23, 14, 4, 13, 17, 15, 12, 14, 15, 4, 1, 13, 10, 15, 12, 9, 13, 11, 15, 7, 21, 21, 15, 15, 15, 7, 16, 20, 8, 15, 6, 20, 6, 6, 1, 21, 0, 4, 9, 8, 6, 16, 15, 3, 15, 6, 20, 22, 19, 15, 2, 16, 15, 16, 19, 8, 15, 22, 13, 15, 8, 20, 5, 6, 6, 0, 2, 15, 7, 20, 15, 11, 9, 16, 16, 15, 7, 5, 16, 11, 15, 15, 15, 3, 8, 15, 19, 3, 5, 10, 16, 15, 5, 15, 13, 2, 11, 19, 16, 5, 22, 15, 6, 19, 1, 14, 15, 11, 15, 17, 9, 15, 8, 15, 4, 11, 5, 2, 5, 9, 20, 1, 15, 10, 16, 11, 23, 15, 19, 15, 8, 17, 12, 20, 20, 15, 22, 7, 5, 3, 15, 2, 15, 1, 9, 8, 10, 12, 14, 8, 3, 15, 18, 14, 1, 15, 16, 15, 15, 2, 10, 15, 9, 15, 5, 8, 15, 12, 15, 13, 15, 15, 0, 15, 0, 15, 20, 19, 6, 10, 5, 7, 18, 8, 15, 4, 16, 15, 10, 15, 8, 22, 20, 7, 22, 6, 15, 12, 15, 20, 15, 7, 15, 11, 19, 5, 19, 15, 12, 6, 3, 16, 19, 3, 3, 4, 7, 11, 15, 22, 4, 12, 15, 15, 15, 15, 7, 9, 10, 15, 18, 19, 15, 20, 4, 10, 7, 6, 10, 17, 15, 14, 21, 20, 15, 0, 9, 9, 17, 15, 19, 15, 21, 9, 15, 13, 21, 3, 14, 2, 15, 10, 15, 15, 2, 10, 15, 4, 6, 5, 15, 5, 0, 12, 5, 10, 2, 15, 6, 16, 5, 18, 15, 0, 9, 7, 15, 7, 12, 8, 6, 15, 15, 9, 11, 10, 16, 16, 4, 15, 15, 6, 8, 14, 6, 9, 22, 8, 15, 21, 17, 21, 15, 15, 23, 23, 7, 21, 19, 15, 4, 15, 15, 15, 0, 22, 15, 12, 8, 20, 14, 2, 11, 15, 8, 10, 12, 8, 15, 19, 15, 7, 7, 6, 0, 15, 15, 5, 13, 13, 15, 15, 3, 5, 15, 16, 9, 0, 21, 18, 14, 7, 15, 15, 21, 10, 2, 9, 7, 15, 15, 5, 9, 15, 14, 16, 5, 15, 15, 14, 9, 16, 14, 2, 6, 2, 13, 1, 7, 15, 0, 9, 15, 6, 13, 15, 21, 3, 14, 2, 3, 15, 15, 15, 15, 16, 8, 15, 18, 20, 15, 1, 5, 15, 13, 4, 9, 15, 6, 15, 20, 15, 8, 12, 15, 15, 15, 4, 15, 17, 16, 12, 7, 7, 15, 6, 4, 15, 22, 15, 5, 21, 9, 9, 7, 15, 20, 15, 16, 15, 0, 1, 6, 6, 15, 15, 15, 15, 9, 2, 4, 15, 15, 14, 0, 0, 10, 13, 9, 22, 14, 15, 11, 15, 19, 1, 7, 12, 12, 8, 15, 21, 13, 11, 6, 14, 10, 15, 8, 16, 13, 4, 16, 5, 9, 1, 15, 20, 9, 13, 14, 18, 8, 7, 2, 12, 11, 21, 7, 22, 10, 3, 8, 22, 3, 13, 8, 8, 15, 15, 11, 15, 20, 20, 17, 16, 22, 11, 12, 15, 20, 6, 15, 18, 22, 16, 15, 15, 8, 6, 15, 11, 17, 10, 19, 15, 19, 21, 20, 21, 13, 6, 13, 21, 15, 11, 15, 6, 3, 15, 5, 10, 11, 15, 6, 5, 15, 20, 0, 13, 18, 3, 10, 9, 11, 15, 3, 6, 15, 13, 10, 16, 7, 9, 2, 14, 9, 10, 9, 22, 18, 16, 15, 15, 7, 15, 17, 11, 15, 15, 4, 17, 18, 9, 15, 15, 8, 1, 22, 15, 17, 0, 12, 21, 0, 16, 15, 9, 13, 17, 10, 16, 15, 14, 7, 16, 14, 9, 17, 15, 9, 9, 11, 15, 0, 9, 10, 7, 7, 1, 16, 19, 18, 1, 7, 13, 15, 20, 9, 12, 16, 5, 19, 9, 6, 1, 5, 4, 0, 15, 15, 0, 22, 21, 13, 15, 10, 10, 15, 9, 3, 2, 15, 1, 15, 10, 18, 15, 6, 11, 15, 13, 15, 15, 3, 2, 10, 7, 17, 5, 1, 0, 12, 16, 15, 9, 3, 0, 15, 3, 17, 9, 15, 4, 3, 8, 9, 4, 7, 7, 15, 15, 0, 15, 10, 15, 9, 6, 4, 15, 9, 7, 5, 13, 5, 8, 19, 15, 15, 13, 17, 16, 16, 7, 15, 20, 15, 0, 1, 15, 6, 13, 15, 10, 15, 19, 18, 15, 8, 15, 12, 8, 15, 19, 18, 6, 12, 14, 12, 0, 16, 22, 15, 15, 18, 15, 17, 19, 18, 15, 15, 22, 14, 6, 15, 2, 16, 20, 15, 7, 15, 9, 16, 15, 9, 3, 11, 13, 0, 7, 17, 8, 11, 3, 15, 7, 10, 8, 15, 1, 21, 6, 16, 14, 3, 18, 15, 17, 20, 15, 19, 6, 12, 10, 8, 15, 6, 8, 15, 6, 15, 10, 2, 17, 21, 8, 12, 9, 7, 3, 3, 20, 2, 15, 15, 15, 4, 11, 11, 5, 9, 20, 15, 1, 16, 15, 23, 5, 8, 17, 13, 11, 15, 15, 2, 15, 15, 7, 15, 15, 15, 15, 18, 5, 13, 15, 18, 15, 10, 4, 9, 18, 2, 7, 11, 12, 6, 15, 15, 12, 23, 4, 5, 7, 8, 20, 8, 4, 10, 11, 15, 10, 15, 15, 5, 15, 17, 7, 1, 4, 20, 3, 11, 8, 15, 15, 9, 7, 9, 8, 3, 3, 18, 15, 12, 12, 2, 10, 4, 15, 15, 13, 1, 19, 17, 15, 17, 7, 6, 3, 11, 9, 20, 15, 2, 9, 4, 21, 15, 12, 15, 3, 15, 12, 16, 13, 6, 11, 16, 5, 0, 10, 0, 10, 21, 18, 15, 6, 22, 9, 20, 15, 13, 10, 8, 16, 1, 15, 7, 16, 2, 21, ...

# %%
device_data = bio_data.groupby(['device_make']).agg({'device_make': ['count']})
device_data.columns = ['count']
device_data = device_data.reset_index()
print(tabulate(device_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤═══════════════╤═════════╕
# │    │ device_make   │   count │
# ╞════╪═══════════════╪═════════╡
# │  0 │ 5008Y_EEA     │       1 │
# ├────┼───────────────┼─────────┤
# │  1 │ 5099Y         │       1 │
# ├────┼───────────────┼─────────┤
# │  2 │ 6039Y         │       1 │
# ├────┼───────────────┼─────────┤
# │  3 │ A0001         │       2 │
# ├────┼───────────────┼─────────┤
# │  4 │ ALE-L21       │       1 │
# ╘════╧═══════════════╧═════════╛

# %%
fig = px.histogram(bio_data, x="device_make")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="349b6ebe-caaa-417e-8fb3-23c165760390" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("349b6ebe-caaa-417e-8fb3-23c165760390")) {
#                     Plotly.newPlot(
#                         '349b6ebe-caaa-417e-8fb3-23c165760390',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "device_make=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["Generic Smartphone", "Generic Smartphone", "E5823", "Samsung SM-A705FN", "Generic Smartphone", "Samsung SM-G960F", "Generic Smartphone", "Samsung SM-G973F", "Generic Smartphone", "Generic Smartphone", "iPhone", "Samsung SM-G935F", "Generic Smartphone", "Samsung SM-G973F", "Samsung SM-G960F", "HTC One", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "LG-$2", "Samsung SM-A202F", "Generic Smartphone", "iPhone", "iPhone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "XT1032", "Generic Smartphone", "COL-L29", "Generic Smartphone", "Samsung SM-N960U1", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Samsung SM-A715F", "Generic Smartphone", "Samsung SM-G930F", "Samsung SM-G960F", "Generic Smartphone", "I3312", "Samsung SM-G950F", "Generic Smartphone", "Generic Smartphone", "FIG-LX1", "iPhone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Samsung SM-G920F", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "MRD-LX1", "Generic Smartphone", "Samsung SM-G930F", "Samsung SM-G935F", "Samsung SM-A202F", "Generic Smartphone", "I3312", "Samsung SM-N950F", "Generic Smartphone", "Generic Smartphone", "Samsung SM-G950F", "iPhone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Moto $2", "Generic Smartphone", "Samsung SM-G970F", "Generic Smartphone", "Samsung GT-I9505", "Generic Smartphone", "Samsung SM-G930F", "Samsung SM-G981B", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "iPhone", "Generic Smartphone", "Generic Smartphone", "Pixel 3a", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Samsung SM-J600FN", "Generic Smartphone", "Samsung SM-A105FN", "Generic Smartphone", "iPhone", "Generic Smartphone", "Generic Smartphone", "OnePlus ONEPLUS A3003", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Samsung SM-G970F", "POT-LX1", "Samsung SM-G950F", "Samsung SM-A202F", "Samsung SM-G960F", "Samsung SM-G950F", "Samsung SM-G975F", "Samsung SM-G973F", "Samsung SM-G930F", "Samsung SM-G950F", "Generic Smartphone", "Samsung SM-J330FN", "Generic Smartphone", "Samsung SM-G770F", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "H3311", "Samsung SM-G981B", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "MAR-LX1A", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "MAR-LX1A", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "iPhone", "Generic Smartphone", "Samsung SM-G935F", "Samsung SM-G960F", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "HTC One $2", "Generic Smartphone", "iPhone", "Generic Smartphone", "Generic Smartphone", "Samsung SM-G950F", "Samsung SM-G965F", "Samsung SM-G973F", "Generic Smartphone", "ELE-L09", "Generic Smartphone", "LG-$2", "iPhone", "Samsung SM-J415FN", "Generic Smartphone", "Samsung SM-G900F", "Generic Smartphone", "Lenovo A1010a20", "Generic Smartphone", "iPhone", "CLT-L09", "Generic Smartphone", "Samsung SM-G973F", "Generic Smartphone", "iPhone", "HTC Desire $2", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Generic Smartphone", "Samsung SM-A705FN", "Generic Smartphone", "Generic Smartphone", "Samsung SM-G980F", "Generic Smartphone", "iPhone", " ...

# %%
experiment_groups = bio_data.groupby(['experiment']).agg({'experiment': ['count']})
experiment_groups.columns = ['count']
experiment_groups = experiment_groups.reset_index()
print(tabulate(experiment_groups, headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤══════════════╤═════════╕
# │    │ experiment   │   count │
# ╞════╪══════════════╪═════════╡
# │  0 │ control      │    4071 │
# ├────┼──────────────┼─────────┤
# │  1 │ exposed      │    4006 │
# ╘════╧══════════════╧═════════╛

# %%
fig = px.histogram(bio_data, x="experiment")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3072814d-975c-4a49-a987-ff3a4d3824c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3072814d-975c-4a49-a987-ff3a4d3824c6")) {
#                     Plotly.newPlot(
#                         '3072814d-975c-4a49-a987-ff3a4d3824c6',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "experiment=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["exposed", "exposed", "exposed", "control", "control", "control", "control", "control", "exposed", "control", "control", "control", "control", "exposed", "exposed", "exposed", "exposed", "control", "exposed", "control", "exposed", "control", "control", "control", "exposed", "exposed", "control", "control", "control", "control", "exposed", "exposed", "exposed", "control", "exposed", "control", "exposed", "exposed", "control", "exposed", "control", "control", "control", "exposed", "control", "control", "exposed", "exposed", "control", "exposed", "exposed", "control", "exposed", "exposed", "control", "exposed", "exposed", "control", "exposed", "exposed", "exposed", "control", "control", "exposed", "control", "exposed", "exposed", "control", "exposed", "exposed", "control", "control", "control", "control", "control", "exposed", "control", "control", "control", "exposed", "exposed", "exposed", "exposed", "exposed", "control", "control", "exposed", "exposed", "control", "exposed", "exposed", "control", "control", "control", "control", "exposed", "control", "exposed", "control", "control", "control", "control", "exposed", "control", "exposed", "control", "control", "control", "control", "exposed", "exposed", "exposed", "exposed", "control", "control", "exposed", "control", "control", "control", "control", "exposed", "exposed", "control", "control", "control", "exposed", "control", "control", "exposed", "control", "control", "control", "exposed", "exposed", "control", "exposed", "control", "exposed", "exposed", "control", "control", "exposed", "exposed", "exposed", "exposed", "exposed", "exposed", "control", "exposed", "exposed", "control", "exposed", "exposed", "exposed", "control", "control", "exposed", "control", "control", "control", "control", "control", "control", "control", "control", "exposed", "exposed", "exposed", "control", "control", "exposed", "control", "control", "exposed", "exposed", "exposed", "control", "exposed", "control", "control", "control", "control", "exposed", "control", "control", "exposed", "exposed", "exposed", "control", "control", "exposed", "control", "exposed", "exposed", "exposed", "exposed", "control", "exposed", "exposed", "exposed", "control", "control", "exposed", "exposed", "control", "control", "control", "control", "exposed", "control", "control", "control", "control", "exposed", "control", "control", "exposed", "control", "exposed", "control", "control", "control", "control", "exposed", "exposed", "exposed", "control", "exposed", "exposed", "exposed", "exposed", "exposed", "control", "exposed", "control", "exposed", "control", "control", "exposed", "control", "control", "exposed", "control", "exposed", "exposed", "control", "control", "control", "exposed", "control", "exposed", "exposed", "exposed", "control", "control", "exposed", "exposed", "exposed", "exposed", "exposed", "control", "exposed", "exposed", "exposed", "exposed", "exposed", "control", "exposed", "exposed", "control", "control", "control", "control", "control", "control", "exposed", "exposed", "exposed", "control", "control", "exposed", "control", "exposed", "exposed", "exposed", "control", "control", "control", "exposed", "control", "exposed", "exposed", "exposed", "control", "control", "exposed", "control", "exposed", "control", "exposed", "control", "exposed", "control", "control", "control", "exposed", "exposed", "control", "exposed", "control", "control", "control", "control", "control", "control", "control", "exposed", "control", "exposed", "control", "control", "control", "exposed", "exposed", "exposed", "exposed", "control", "exposed", "control", "exposed", "control", "exposed", "control", "exposed", "exposed", "control", "c ...

# %%
browser_types = bio_data['browser'].value_counts()
browser_types.columns = ['count']
browser_types = browser_types.reset_index()
print(tabulate(browser_types, headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════════════════════════╤═══════════╕
# │    │ index                      │   browser │
# ╞════╪════════════════════════════╪═══════════╡
# │  0 │ Chrome Mobile              │      4554 │
# ├────┼────────────────────────────┼───────────┤
# │  1 │ Chrome Mobile WebView      │      1489 │
# ├────┼────────────────────────────┼───────────┤
# │  2 │ Samsung Internet           │       824 │
# ├────┼────────────────────────────┼───────────┤
# │  3 │ Facebook                   │       764 │
# ├────┼────────────────────────────┼───────────┤
# │  4 │ Mobile Safari              │       337 │
# ├────┼────────────────────────────┼───────────┤
# │  5 │ Chrome Mobile iOS          │        51 │
# ├────┼────────────────────────────┼───────────┤
# │  6 │ Mobile Safari UI/WKWebView │        44 │
# ├────┼────────────────────────────┼───────────┤
# │  7 │ Pinterest                  │         3 │
# ├────┼────────────────────────────┼───────────┤
# │  8 │ Chrome                     │         3 │
# ├────┼────────────────────────────┼───────────┤
# │  9 │ Opera Mobile               │         3 │
# ├────┼────────────────────────────┼───────────┤
# │ 10 │ Edge Mobile                │         1 │
# ├────┼────────────────────────────┼───────────┤
# │ 11 │ Puffin                     │         1 │
# ├────┼────────────────────────────┼───────────┤
# │ 12 │ Firefox Mobile             │         1 │
# ├────┼────────────────────────────┼───────────┤
# │ 13 │ Android                    │         1 │
# ├────┼────────────────────────────┼───────────┤
# │ 14 │ Opera Mini                 │         1 │
# ╘════╧════════════════════════════╧═══════════╛

# %%
fig = px.histogram(bio_data, x="browser")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="96474647-2f5d-4df1-a712-42dbfb2a20a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("96474647-2f5d-4df1-a712-42dbfb2a20a3")) {
#                     Plotly.newPlot(
#                         '96474647-2f5d-4df1-a712-42dbfb2a20a3',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "browser=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Facebook", "Chrome Mobile", "Facebook", "Chrome Mobile", "Facebook", "Chrome Mobile WebView", "Chrome Mobile", "Mobile Safari", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Facebook", "Chrome Mobile", "Chrome Mobile iOS", "Mobile Safari", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Facebook", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Samsung Internet", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile WebView", "Mobile Safari", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Facebook", "Chrome Mobile", "Samsung Internet", "Facebook", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile WebView", "Samsung Internet", "Chrome Mobile", "Chrome Mobile", "Facebook", "Mobile Safari UI/WKWebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Samsung Internet", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Mobile Safari", "Chrome Mobile", "Chrome Mobile", "Facebook", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Samsung Internet", "Chrome Mobile", "Mobile Safari", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Samsung Internet", "Chrome Mobile WebView", "Chrome Mobile WebView", "Facebook", "Facebook", "Facebook", "Facebook", "Facebook", "Facebook", "Facebook", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Samsung Internet", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Facebook", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile iOS", "Chrome Mobile", "Facebook", "Chrome Mobile WebView", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Mobile Safari", "Chrome Mobile", "Chrome Mobile", "Samsung Internet", "Facebook", "Facebook", "Chrome Mobile", "Facebook", "Chrome Mobile", "Chrome Mobile", "Mobile Safari", "Samsung Internet", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile iOS", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Mobile Safari", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Samsung Internet", "Chrome Mobile", "Mobile Safari", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile WebView", "Chrome Mobile", "Facebook", "Chrome Mobile", "Chrome Mobile", "Chrome Mobile", "Facebook", "Chrome Mobile", "Chrome Mobile  ...

# %%
bio_data.isnull().sum() #checking for any null values in our data
# Out:
# auction_id     0
# experiment     0
# date           0
# hour           0
# device_make    0
# platform_os    0
# browser        0
# yes            0
# no             0
# dtype: int64

# %%
exposed_data=bio_data[bio_data['experiment'] == 'exposed']

# %%
exposed_data
# Out:
#                                 auction_id experiment  ... yes  no
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  ...   0   0
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed  ...   0   0
# 2     0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  ...   0   1
# 8     004940f5-c642-417a-8fd2-c8e5d989f358    exposed  ...   0   0
# 13    006b9c6e-5f5d-4385-a811-ff20a24b30ac    exposed  ...   0   0
# ...                                    ...        ...  ...  ..  ..
# 8065  ffbc02cb-628a-4de5-87fc-5d76b7d796e5    exposed  ...   0   0
# 8067  ffc594ef-756c-4d24-a310-0d8eb4e11eb7    exposed  ...   0   0
# 8071  ffdfdc09-48c7-4bfb-80f8-ec1eb633602b    exposed  ...   0   1
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  ...   0   0
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  ...   0   0
#
# [4006 rows x 9 columns]

# %%
exposed_date_data = exposed_data.groupby(['date']).agg({'date': ['count']})
exposed_date_data.columns = ['count']
exposed_date_data = exposed_date_data.reset_index()
print(tabulate(exposed_date_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════════╤═════════╕
# │    │ date       │   count │
# ╞════╪════════════╪═════════╡
# │  0 │ 2020-07-03 │     470 │
# ├────┼────────────┼─────────┤
# │  1 │ 2020-07-04 │     477 │
# ├────┼────────────┼─────────┤
# │  2 │ 2020-07-05 │     528 │
# ├────┼────────────┼─────────┤
# │  3 │ 2020-07-06 │     294 │
# ├────┼────────────┼─────────┤
# │  4 │ 2020-07-07 │     257 │
# ╘════╧════════════╧═════════╛

# %%
exposed_hour_data = exposed_data.groupby(['hour']).agg({'hour': ['count']})
exposed_hour_data.columns = ['count']
exposed_hour_data = exposed_hour_data.reset_index()
print(tabulate(exposed_hour_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════╤═════════╕
# │    │   hour │   count │
# ╞════╪════════╪═════════╡
# │  0 │      0 │     104 │
# ├────┼────────┼─────────┤
# │  1 │      1 │     138 │
# ├────┼────────┼─────────┤
# │  2 │      2 │     139 │
# ├────┼────────┼─────────┤
# │  3 │      3 │     161 │
# ├────┼────────┼─────────┤
# │  4 │      4 │     173 │
# ╘════╧════════╧═════════╛

# %%
exposed_device_data = exposed_data.groupby(['device_make']).agg({'device_make': ['count']})
exposed_device_data.columns = ['count']
exposed_device_data = exposed_device_data.reset_index()
print(tabulate(exposed_device_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤═══════════════╤═════════╕
# │    │ device_make   │   count │
# ╞════╪═══════════════╪═════════╡
# │  0 │ 5099Y         │       1 │
# ├────┼───────────────┼─────────┤
# │  1 │ 6039Y         │       1 │
# ├────┼───────────────┼─────────┤
# │  2 │ A0001         │       1 │
# ├────┼───────────────┼─────────┤
# │  3 │ ALE-L21       │       1 │
# ├────┼───────────────┼─────────┤
# │  4 │ ANE-LX1       │       9 │
# ╘════╧═══════════════╧═════════╛

# %%
exposed_browser_types = exposed_data['browser'].value_counts()
exposed_browser_types.columns = ['count']
exposed_browser_types = exposed_browser_types.reset_index()
print(tabulate(exposed_browser_types, headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════════════════════════╤═══════════╕
# │    │ index                      │   browser │
# ╞════╪════════════════════════════╪═══════════╡
# │  0 │ Chrome Mobile              │      2144 │
# ├────┼────────────────────────────┼───────────┤
# │  1 │ Chrome Mobile WebView      │      1197 │
# ├────┼────────────────────────────┼───────────┤
# │  2 │ Samsung Internet           │       332 │
# ├────┼────────────────────────────┼───────────┤
# │  3 │ Facebook                   │       203 │
# ├────┼────────────────────────────┼───────────┤
# │  4 │ Mobile Safari              │        91 │
# ├────┼────────────────────────────┼───────────┤
# │  5 │ Chrome Mobile iOS          │        17 │
# ├────┼────────────────────────────┼───────────┤
# │  6 │ Mobile Safari UI/WKWebView │        14 │
# ├────┼────────────────────────────┼───────────┤
# │  7 │ Opera Mobile               │         3 │
# ├────┼────────────────────────────┼───────────┤
# │  8 │ Chrome                     │         2 │
# ├────┼────────────────────────────┼───────────┤
# │  9 │ Pinterest                  │         1 │
# ├────┼────────────────────────────┼───────────┤
# │ 10 │ Edge Mobile                │         1 │
# ├────┼────────────────────────────┼───────────┤
# │ 11 │ Firefox Mobile             │         1 │
# ╘════╧════════════════════════════╧═══════════╛

# %%
control_data=bio_data[bio_data['experiment'] == 'control']

# %%
control_data
# Out:
#                                 auction_id experiment  ... yes  no
# 3     00187412-2932-4542-a8ef-3633901c98d9    control  ...   0   0
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control  ...   0   0
# 5     0027ce48-d3c6-4935-bb12-dfb5d5627857    control  ...   0   0
# 6     002e308b-1a07-49d6-8560-0fbcdcd71e4b    control  ...   0   0
# 7     00393fb9-ca32-40c0-bfcb-1bd83f319820    control  ...   0   0
# ...                                    ...        ...  ...  ..  ..
# 8069  ffca1153-c182-4f32-9e90-2a6008417497    control  ...   0   1
# 8070  ffcea781-a6e7-4f98-9d90-f95377270476    control  ...   0   0
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  ...   0   0
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  ...   0   0
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  ...   0   0
#
# [4071 rows x 9 columns]

# %%
control_date_data = control_data.groupby(['date']).agg({'date': ['count']})
control_date_data.columns = ['count']
control_date_data = control_date_data.reset_index()
print(tabulate(control_date_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════════╤═════════╕
# │    │ date       │   count │
# ╞════╪════════════╪═════════╡
# │  0 │ 2020-07-03 │    1545 │
# ├────┼────────────┼─────────┤
# │  1 │ 2020-07-04 │     426 │
# ├────┼────────────┼─────────┤
# │  2 │ 2020-07-05 │     362 │
# ├────┼────────────┼─────────┤
# │  3 │ 2020-07-06 │     196 │
# ├────┼────────────┼─────────┤
# │  4 │ 2020-07-07 │     223 │
# ╘════╧════════════╧═════════╛

# %%
control_hour_data = control_data.groupby(['hour']).agg({'hour': ['count']})
control_hour_data.columns = ['count']
control_hour_data = control_hour_data.reset_index()
print(tabulate(control_hour_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════╤═════════╕
# │    │   hour │   count │
# ╞════╪════════╪═════════╡
# │  0 │      0 │      90 │
# ├────┼────────┼─────────┤
# │  1 │      1 │      84 │
# ├────┼────────┼─────────┤
# │  2 │      2 │      91 │
# ├────┼────────┼─────────┤
# │  3 │      3 │     105 │
# ├────┼────────┼─────────┤
# │  4 │      4 │     108 │
# ╘════╧════════╧═════════╛

# %%
control_device_data = control_data.groupby(['device_make']).agg({'device_make': ['count']})
control_device_data.columns = ['count']
control_device_data = control_device_data.reset_index()
print(tabulate(control_device_data.head(), headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤═══════════════╤═════════╕
# │    │ device_make   │   count │
# ╞════╪═══════════════╪═════════╡
# │  0 │ 5008Y_EEA     │       1 │
# ├────┼───────────────┼─────────┤
# │  1 │ A0001         │       1 │
# ├────┼───────────────┼─────────┤
# │  2 │ ANE-LX1       │       9 │
# ├────┼───────────────┼─────────┤
# │  3 │ ATU-L11       │       1 │
# ├────┼───────────────┼─────────┤
# │  4 │ BBF100-1      │       1 │
# ╘════╧═══════════════╧═════════╛

# %%
control_browser_types = control_data['browser'].value_counts()
control_browser_types.columns = ['count']
control_browser_types = control_browser_types.reset_index()
print(tabulate(control_browser_types, headers = 'keys', tablefmt = 'fancy_grid'))
# Out:
# ╒════╤════════════════════════════╤═══════════╕
# │    │ index                      │   browser │
# ╞════╪════════════════════════════╪═══════════╡
# │  0 │ Chrome Mobile              │      2410 │
# ├────┼────────────────────────────┼───────────┤
# │  1 │ Facebook                   │       561 │
# ├────┼────────────────────────────┼───────────┤
# │  2 │ Samsung Internet           │       492 │
# ├────┼────────────────────────────┼───────────┤
# │  3 │ Chrome Mobile WebView      │       292 │
# ├────┼────────────────────────────┼───────────┤
# │  4 │ Mobile Safari              │       246 │
# ├────┼────────────────────────────┼───────────┤
# │  5 │ Chrome Mobile iOS          │        34 │
# ├────┼────────────────────────────┼───────────┤
# │  6 │ Mobile Safari UI/WKWebView │        30 │
# ├────┼────────────────────────────┼───────────┤
# │  7 │ Pinterest                  │         2 │
# ├────┼────────────────────────────┼───────────┤
# │  8 │ Puffin                     │         1 │
# ├────┼────────────────────────────┼───────────┤
# │  9 │ Chrome                     │         1 │
# ├────┼────────────────────────────┼───────────┤
# │ 10 │ Android                    │         1 │
# ├────┼────────────────────────────┼───────────┤
# │ 11 │ Opera Mini                 │         1 │
# ╘════╧════════════════════════════╧═══════════╛

# %% [markdown]
# ## Correlation Analysis

# %%
# Step 1 - Make a scatter plot with square markers, set column names as labels

def heatmap(x, y, size):
    fig, ax = plt.subplots()
    
    # Mapping from column names to integer coordinates
    x_labels = [v for v in sorted(x.unique())]
    y_labels = [v for v in sorted(y.unique())]
    x_to_num = {p[1]:p[0] for p in enumerate(x_labels)} 
    y_to_num = {p[1]:p[0] for p in enumerate(y_labels)} 
    
    size_scale = 500
    ax.scatter(
        x=x.map(x_to_num), # Use mapping for x
        y=y.map(y_to_num), # Use mapping for y
        s=size * size_scale, # Vector of square sizes, proportional to size parameter
        marker='s' # Use square as scatterplot marker
    )
    
    # Show column labels on the axes
    ax.set_xticks([x_to_num[v] for v in x_labels])
    ax.set_xticklabels(x_labels, rotation=45, horizontalalignment='right')
    ax.set_yticks([y_to_num[v] for v in y_labels])
    ax.set_yticklabels(y_labels)

# %%
columns = [ 'platform_os', 'hour', ] 
df1=pd.get_dummies(bio_data)
corr =bio_data[columns].corr()
corr = pd.melt(corr.reset_index(), id_vars='index') # Unpivot the dataframe, so we can get pair of arrays for x and y
corr.columns = ['x', 'y', 'value']

# %%
corr
# Out:
#              x            y     value
# 0  platform_os  platform_os  1.000000
# 1         hour  platform_os  0.000062
# 2  platform_os         hour  0.000062
# 3         hour         hour  1.000000

# %%
heatmap(
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs()
)

# %% [markdown]
# ## Classical A/B Testing
